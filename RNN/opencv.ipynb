# %%
import cv2
import numpy as np

img = cv2.imread("cat.jpg")

rows, cols = img.shape[:2]

shear = 0.5

M = np.float32([
    [1, shear, 0],
    [0, 1, 0]
])

sheared = cv2.warpAffine(img, M, (int(cols + rows * shear), rows))

cv2.imshow("Original", img)
cv2.imshow("Sheared", sheared)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt

img = cv2.imread('cat.jpg')

rows,cols = img.shape[:2]

tx = 100
ty = 50

M = np.float32([
    [1,0,tx],
    [0,1,ty]
])

translated = cv2.warpAffine(img,M,(cols,rows))
plt.imshow(translated)

# %%
plt.imshow(img)

# %%
zoom = cv2.resize(img,None,fx=2,fy=2)

h,w = img.shape[:2]

zoomed_view = zoom[h//2:h//2+h, w//2:w//2+w]

plt.imshow(zoomed_view)

# %%
zoom = cv2.resize(img,None,fx=2,fy=2)

h,w = img.shape[:2]

zoomed_view = zoom[h//2:h//2+h, w//2:w//2+w]

plt.imshow(zoomed_view)

# %%
tx=100
ty=50
w,h = img.shape[:2]
M=np.float32([
    [1,0,tx],
    [0,1,ty]
])

translated = cv2.warpAffine(img,M,(w,h))

plt.imshow(translated)

# %%
mean=0
std=25
gaussian=np.random.normal(mean,std,img.shape)

noisy_img = img+gaussian

noisy_img = np.clip(noisy_img,0,255).astype(np.uint8)

plt.imshow(noisy_img)

# %%
mean =0
std=25
guassian = np.random.normal(mean,std,img.shape)

noisy_img = img+guassian

noisy_img = np.clip(noisy_img,0,255).astype(np.uint8)

plt.imshow(noisy_img)

# %%
normalized = img/255.0

# plt.imshow(normalized)

normalized
# Out:
# array([[[0.10980392, 0.10980392, 0.10980392],
#         [0.10196078, 0.10196078, 0.10196078],
#         [0.10980392, 0.10980392, 0.10980392],
#         ...,
#         [0.17647059, 0.17647059, 0.17647059],
#         [0.1372549 , 0.1372549 , 0.1372549 ],
#         [0.09411765, 0.09411765, 0.09411765]],
#
#        [[0.10980392, 0.10980392, 0.10980392],
#         [0.10588235, 0.10588235, 0.10588235],
#         [0.10980392, 0.10980392, 0.10980392],
#         ...,
#         [0.17254902, 0.17254902, 0.17254902],
#         [0.12941176, 0.12941176, 0.12941176],
#         [0.09019608, 0.09019608, 0.09019608]],
#
#        [[0.11764706, 0.11764706, 0.11764706],
#         [0.10980392, 0.10980392, 0.10980392],
#         [0.11764706, 0.11764706, 0.11764706],
#         ...,
#         [0.16470588, 0.16470588, 0.16470588],
#         [0.12941176, 0.12941176, 0.12941176],
#         [0.08627451, 0.08627451, 0.08627451]],
#
#        ...,
#
#        [[0.03921569, 0.03921569, 0.03921569],
# ...

# %%
w,h = img.shape[:2]

tx = 100
ty= 50
M = np.float32([
    [1,0,tx],
    [0,1,ty]
])

translated = cv2.warpAffine(img,M,(w,h))
plt.imshow(translated)

# %%
zoom = cv2.resize(img,None,fx=2,fy=2)
h,w = img.shape[:2]
zoomed_view = zoom[h//2:h//2+h, w//2:w//2+w]

plt.imshow(zoomed_view)

# %%
mean=0
std=25
noise = np.random.normal(mean,std,img.shape)
noisy_img = img+noise

noisy_img = np.clip(noisy_img,0,255).astype(np.uint8)
plt.imshow(noisy_img)
