# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sales_data = {
    "date": [
        "2021-01-01", "2021-02-01", "2021-03-01", "2021-04-01",
        "2021-05-01", "2021-06-01", "2021-07-01", "2021-08-01",
        "2021-09-01", "2021-10-01", "2021-11-01", "2021-12-01",

        "2022-01-01", "2022-02-01", "2022-03-01", "2022-04-01",
        "2022-05-01", "2022-06-01", "2022-07-01", "2022-08-01",
        "2022-09-01", "2022-10-01", "2022-11-01", "2022-12-01",

        "2023-01-01", "2023-02-01", "2023-03-01", "2023-04-01",
        "2023-05-01", "2023-06-01", "2023-07-01", "2023-08-01",
        "2023-09-01", "2023-10-01", "2023-11-01", "2023-12-01",

        "2024-01-01", "2024-02-01", "2024-03-01", "2024-04-01",
        "2024-05-01", "2024-06-01", "2024-07-01", "2024-08-01",
        "2024-09-01", "2024-10-01", "2024-11-01", "2024-12-01",

        "2025-01-01", "2025-02-01", "2025-03-01", "2025-04-01",
        "2025-05-01", "2025-06-01", "2025-07-01", "2025-08-01",
        "2025-09-01", "2025-10-01", "2025-11-01", "2025-12-01"
    ],

    "sales": [
        120, 128, 135, 142, 150, 158, 165, 170, 180, 205, 225, 260,
        135, 142, 150, 158, 166, 174, 182, 190, 202, 225, 248, 285,
        150, 158, 167, 175, 184, 193, 202, 212, 225, 250, 275, 315,
        168, 176, 185, 195, 205, 215, 226, 237, 250, 278, 305, 350,
        185, 194, 204, 215, 226, 237, 249, 262, 276, 305, 335, 385
    ]
}

# %%
df = pd.DataFrame(sales_data)

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df.set_index(df['date'],inplace=True)

# %%
df.head()
# Out:
#                  date  sales
# date
# 2021-01-01 2021-01-01    120
# 2021-02-01 2021-02-01    128
# 2021-03-01 2021-03-01    135
# 2021-04-01 2021-04-01    142
# 2021-05-01 2021-05-01    150

# %%
plt.figure(figsize=(8,4))
plt.plot(df['sales'],marker='o')
plt.xlabel('Year')
plt.ylabel('No. of sales')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

df['sales_diff']  = df['sales'].diff()
diff_df = df['sales_diff'].dropna()

# %%
result = adfuller(diff_df)
print('p-value',result[1])
# Out:
# p-value 0.6566613207324771
