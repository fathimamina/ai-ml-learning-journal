# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\MINA\Documents\WeekilyPrac\Ml_JOUNRAL\ml-learning-journal\Time Series\Datasets\shampoo_sales.csv')

df.head()
# Out:
#   Month  Sales
# 0  1-01  266.0
# 1  1-02  145.9
# 2  1-03  183.1
# 3  1-04  119.3
# 4  1-05  180.3

# %%
df.columns
# Out:
# Index(['Month', 'Sales'], dtype='str')

# %%
# df[['Year','Month_No.']] = df['Month'].str.split('-', expand=True)

# df['Year'] = df['Year'].astype(int)
# df['Month_No'] = df['Month_No.'].astype(int)

# %%
df["Month"] = pd.to_datetime(df["Month"])

df.head()
# Out:
# C:\Users\MINA\AppData\Local\Temp\ipykernel_3748\2539410801.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Month"] = pd.to_datetime(df["Month"])
#     Month  Sales
# 0 1-01-01  266.0
# 1 1-01-02  145.9
# 2 1-01-03  183.1
# 3 1-01-04  119.3
# 4 1-01-05  180.3

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(
    df['Sales'],
    model='addictive',
    period=12
)

decomposition.plot()
plt.show()

# %%
decomposition.trend
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6     193.470833
# 7     190.633333
# 8     191.908333
# 9     199.450000
# 10    206.329167
# 11    211.729167
# 12    216.425000
# 13    219.479167
# 14    226.820833
# 15    243.312500
# 16    252.758333
# 17    256.275000
# 18    268.850000
# 19    287.029167
# 20    303.558333
# 21    314.883333
# 22    330.545833
# 23    345.558333
# 24    366.387500
# 25    385.283333
# 26    405.954167
# 27    424.529167
# 28    439.966667
# 29    465.858333
# 30           NaN
# 31           NaN
# 32           NaN
# 33           NaN
# 34           NaN
# 35           NaN
# Name: trend, dtype: float64

# %%
decomposition.seasonal
# Out:
# 0    -19.193924
# 1     -2.218924
# 2    -48.175174
# 3     27.591493
# 4    -44.800174
# 5      6.345660
# 6      2.951910
# 7     30.431076
# 8     -1.171007
# 9     20.295660
# 10    37.274826
# 11    -9.331424
# 12   -19.193924
# 13    -2.218924
# 14   -48.175174
# 15    27.591493
# 16   -44.800174
# 17     6.345660
# 18     2.951910
# 19    30.431076
# 20    -1.171007
# 21    20.295660
# 22    37.274826
# 23    -9.331424
# 24   -19.193924
# 25    -2.218924
# 26   -48.175174
# 27    27.591493
# 28   -44.800174
# 29     6.345660
# 30     2.951910
# 31    30.431076
# 32    -1.171007
# 33    20.295660
# 34    37.274826
# 35    -9.331424
# Name: seasonal, dtype: float64

# %%
decomposition.resid
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6      35.377257
# 7       3.435590
# 8       2.062674
# 9     -96.845660
# 10     92.896007
# 11    -16.497743
# 12     -2.931076
# 13    -67.760243
# 14     31.454340
# 15      2.396007
# 16    -16.558160
# 17     24.379340
# 18    -45.801910
# 19    -13.860243
# 20    -12.487326
# 21     86.421007
# 22   -103.320660
# 23      6.073090
# 24     -7.493576
# 25     57.335590
# 26    -41.878993
# 27    -12.820660
# 28      6.133507
# 29    -34.803993
# 30           NaN
# 31           NaN
# 32           NaN
# 33           NaN
# 34           NaN
# 35           NaN
# Name: resid, dtype: float64

# %%
decomposition.observed
# Out:
# 0     266.0
# 1     145.9
# 2     183.1
# 3     119.3
# 4     180.3
# 5     168.5
# 6     231.8
# 7     224.5
# 8     192.8
# 9     122.9
# 10    336.5
# 11    185.9
# 12    194.3
# 13    149.5
# 14    210.1
# 15    273.3
# 16    191.4
# 17    287.0
# 18    226.0
# 19    303.6
# 20    289.9
# 21    421.6
# 22    264.5
# 23    342.3
# 24    339.7
# 25    440.4
# 26    315.9
# 27    439.3
# 28    401.3
# 29    437.4
# 30    575.5
# 31    407.6
# 32    682.0
# 33    475.3
# 34    581.3
# 35    646.9
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10,4))
plt.plot(decomposition.trend)
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(decomposition.seasonal)
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.plot(decomposition.resid)
plt.show()
