# %%
import pandas as pd

df = pd.read_csv('sales.csv')

df.head()
# Out:
#          Date  Sales
# 0  2024-01-31    120
# 1  2024-02-29    125
# 2  2024-03-31    123
# 3  2024-04-30    130
# 4  2024-05-31    135

# %%
df.set_index(df['Date'], inplace=True)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

plt.plot(df['Sales'])
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(df['Sales'])

# print(result)
print('p-value', result[1])
# Out:
# p-value 0.9990834791057953

# %%
if result[1]<0.05:
    print('Sationary')
else:
    print('Non Stationary')
# Out:
# Non Stationary
