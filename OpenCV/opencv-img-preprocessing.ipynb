# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('Images/reference.jpg')
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
resized = cv2.resize(image,(300,300))

plt.imshow(resized)
plt.axis('off')
plt.show()

# %%
cropped = image[100:1000, 300:400]

plt.imshow(cropped)
plt.axis('off')
plt.show()

# %%
horizondal = cv2.flip(image,1)
plt.imshow(horizondal)
plt.show()

# %%
normalized = image/255.0
print(normalized.min())
print(normalized.max())
# Out:
# 0.0
# 1.0

# %% [markdown]
# # Blurring & Smoothing

# %%
blur = cv2.blur(image,(5,5))

# %%
gaussian = cv2.GaussianBlur(image,(5,5),0)

# %%
median = cv2.medianBlur(image, 5)

# %%
plt.imshow(gaussian)
plt.axis("off")
plt.show()

# %% [markdown]
# # Thresholding

# %%
gray = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)

# %%
_,thresh = cv2.threshold(
    gray, 127,255,cv2.THRESH_BINARY
)

plt.imshow(thresh,cmap='gray')
plt.show()

# %% [markdown]
# # Morphological Operations

# %%
import numpy as np
kernal = np.ones((5,5),np.uint8)

# %%
# Erosion

erotion = cv2.erode(thresh,kernal,iterations=1)

# %%
# Dilation

dilation = cv2.dilate(thresh,kernal,iterations=1)

# %%
# Opening

opening = cv2.morphologyEx(
    thresh,
    cv2.MORPH_OPEN,
    kernal
)

# %%
# Closing

closing = cv2.morphologyEx(
    thresh,
    cv2.MORPH_CLOSE,
    kernal
)

# %% [markdown]
# - Erosion  -> Shrink
# - Dilation -> Expand
# - Opening  -> Remove noise
# - Closing  -> Fill holes

# %% [markdown]
# # Edge Detection

# %%
gray = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)

# %%
# Canny Edge Detector
edges = cv2.Canny(
    gray,
    100,
    200
)

# %%
plt.imshow(edges,cmap='gray')
plt.show()
